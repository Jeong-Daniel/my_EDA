# %%
#필요 라이브러리 불러오기
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_sleep = pd.read_csv('./Personal Sleep Data.csv')
df_sleep = df_sleep[['월','일','수면','시간','수면효율']]
df_sleep = df_sleep.dropna()

# %%
df_sleep.sort_values('수면효율',ascending=False).head(15)
# Out:
#      월    일       수면           시간 수면효율
# 15  2월   2일  7시간 48분  01:01~08:49  92%
# 2   1월  20일   7시간 9분  01:21~08:30  91%
# 7   1월  25일  7시간 51분  01:00~08:51  91%
# 91  4월  19일  7시간 34분  23:13~06:47  91%
# 22  2월   9일  5시간 28분  23:10~04:38  91%
# 72  3월  31일  7시간 29분  23:53~07:22  90%
# 3   1월  21일   7시간 0분  01:50~08:50  90%
# 94  4월  22일   8시간 5분  00:08~08:13  90%
# 5   1월  23일  8시간 05분  02:18~10:23  90%
# 10  1월  28일  7시간 30분  01:20~08:50  90%
# 49  3월   8일  7시간 40분  23:54~07:34  90%
# 1   1월  19일   8시간 3분  00:51~08:54  90%
# 39  2월  26일   8시간 5분  22:46~06:51  90%
# 80  4월   8일  6시간 20분  00:38~06:58  90%
# 63  3월  22일  8시간 37분  23:46~08:23  89%
